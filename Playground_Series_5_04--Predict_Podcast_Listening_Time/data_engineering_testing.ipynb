# %%
import pandas as pd
import numpy as np
import seaborn as sns

data_train = pd.read_csv('train.csv')
data_test = pd.read_csv('test.csv')
data_train.sample(5)
# Out:
#             id        Podcast_Name Episode_Title  Episode_Length_minutes  \
# 219648  219648  True Crime Stories    Episode 74                   38.44
# 363498  363498        Daily Digest    Episode 89                   65.82
# 76477    76477   Detective Diaries    Episode 80                   70.86
# 546041  546041         Style Guide    Episode 49                   20.01
# 497187  497187         Gadget Geek    Episode 35                   40.14
#
#              Genre  Host_Popularity_percentage Publication_Day  \
# 219648  True Crime                       31.76        Saturday
# 363498        News                       26.68          Friday
# 76477   True Crime                       76.35          Sunday
# 546041   Lifestyle                       33.67          Sunday
# 497187  Technology                       97.28        Saturday
#
#        Publication_Time  Guest_Popularity_percentage  Number_of_Ads  \
# 219648          Evening                        74.53            3.0
# 363498            Night                          NaN            2.0
# 76477           Morning                        84.99            1.0
# 546041          Evening                        67.34            1.0
# 497187        Afternoon                          NaN            0.0
#
#        Episode_Sentiment  Listening_Time_minutes
# 219648          Positive                37.41929
# 363498          Positive                37.07781
# 76477            Neutral                55.87780
# 546041          Positive                11.48762
# 497187          Negative                32.62992

# %%
# clean data
def clean(dataframe):
    dataframe.drop('id', axis=1, inplace=True)
    dataframe.dropna(axis=0, how='any', inplace=True)
    dataframe.drop(dataframe[dataframe['Number_of_Ads']>10].index, inplace=True)
    dataframe.drop(dataframe[dataframe['Episode_Length_minutes']>250].index, inplace=True)
    dataframe['Episode_Title'] = dataframe['Episode_Title'].map(lambda et: int(et.split()[1]))
    dataframe['Episode_Sentiment'] = dataframe['Episode_Sentiment'].map({'Negative': -1, 'Neutral': 0, 'Positive': +1})
    dataframe['Number_of_Ads'] = dataframe['Number_of_Ads'].astype(int)

    return dataframe

data_train = clean(data_train)
data_test = clean(data_test)
data_train.sample(5)
# Out:
#        Podcast_Name  Episode_Title  Episode_Length_minutes      Genre  \
# 406521  Global News             40                    8.25       News
# 342905    Humor Hub             96                   69.52     Comedy
# 476357     Game Day             24                   30.08     Sports
# 205137  Style Guide             61                   99.59  Lifestyle
# 510258  Global News             36                   39.85       News
#
#         Host_Popularity_percentage Publication_Day Publication_Time  \
# 406521                       46.91       Wednesday            Night
# 342905                       73.36          Friday          Evening
# 476357                       32.08          Sunday          Evening
# 205137                       59.03       Wednesday          Evening
# 510258                       53.77        Saturday            Night
#
#         Guest_Popularity_percentage  Number_of_Ads  Episode_Sentiment  \
# 406521                        17.41              1                 -1
# 342905                        54.13              0                  0
# 476357                        54.32              3                  1
# 205137                        94.88              1                 -1
# 510258                        90.67              0                  1
#
#         Listening_Time_minutes
# 406521                 0.00000
# 342905                28.88347
# 476357                22.55175
# 205137                86.74890
# 510258                20.78210

# %%
categorical_columns = data_train.select_dtypes(include=['category', 'object']).columns.tolist()

print(categorical_columns)
# Out:
# ['Podcast_Name', 'Genre', 'Publication_Day', 'Publication_Time']

# %%
def feature_eng(df):
    for col in ['Genre', 'Podcast_Name', 'Publication_Day', 'Publication_Time', 'Episode_Sentiment']:
        encode_dict = {key: val for val, key in enumerate(df[col].unique())}
        df[col] = df[col].replace(encode_dict)
        df[col] = df[col].astype('category')
    
    return df

data_train = feature_eng(data_train)
data_test = feature_eng(data_test)

# %%
from sklearn.model_selection import train_test_split
data_train, rest = train_test_split(data_train, test_size=0.999)
data_test, rest = train_test_split(data_test, test_size=0.999)
print(data_train)
# Out:
#        Podcast_Name  Episode_Title  Episode_Length_minutes Genre  \
# 192104           14             84                   19.69     2
# 604876           23             73                   23.14     6
# 12284            21              4                   29.49     6
# 220731           41             30                  107.06     4
# 57552            14             30                    7.02     2
# ...             ...            ...                     ...   ...
# 339242           29             73                   50.67     9
# 725848           40             60                  100.20     4
# 644600           27             67                   53.01     8
# 437930           30             37                   71.63     1
# 184847            7             13                   68.07     7
#
#         Host_Popularity_percentage Publication_Day Publication_Time  \
# 192104                       38.27               4                0
# 604876                       89.50               2                2
# 12284                        60.87               4                1
# 220731                       83.97               2                3
# 57552                        24.53               4                1
# ...                            ...             ...              ...
# 339242                       34.55               0                0
# 725848                       56.29               4                3
# 644600                       54.83               0                2
# 437930                       80.84               3                2
# 184847                       43.56               0                1
#
#         Guest_Popularity_percentage  Number_of_Ads Episode_Sentiment  \
# 192104                        91.16              0                 1
# 604876                        93.21              3                 2
# 12284                         78.84              2                 0
# 220731                        92.57              0                 2
# 57552                         30.90              1                 2
# ...                             ...            ...               ...
# 339242                        58.44              3                 2
# 725848                        89.01              2                 2
# 644600                        38.74              1                 2
# 437930                        75.60              1                 1
# 184847                        38.93              3                 0
#
#         Listening_Time_minutes
# 192104                 5.77107
# 604876                 8.80208
# 12284                 21.08184
# 220731                99.41509
# 57552                  5.64000
# ...                        ...
# 339242                24.09000
# 725848                73.39708
# 644600                40.83639
# 437930                54.27710
# 184847                55.89358
#
# [539 rows x 11 columns]

# %%
from itertools import combinations

encode_columns = ['Podcast_Name', 'Episode_Title', 'Episode_Length_minutes', 'Genre', 'Host_Popularity_percentage', 'Publication_Day', 'Publication_Time', 'Guest_Popularity_percentage', 'Number_of_Ads', 'Episode_Sentiment']
#encode_columns = ['Episode_Length_minutes', 'Episode_Title', 'Host_Popularity_percentage', 'Number_of_Ads', 'Episode_Sentiment', 'Publication_Day', 'Publication_Time']
pair_size = [2, 3, 4]

for r in pair_size:
    for cols in list(combinations(encode_columns, r)):
        new_col_name = '_'.join(cols)

        data_train[new_col_name] = data_train[list(cols)].astype(str).agg('_'.join, axis=1)
        data_train[new_col_name] = data_train[new_col_name].astype('category')

        data_test[new_col_name] = data_test[list(cols)].astype(str).agg('_'.join, axis=1)
        data_test[new_col_name] = data_test[new_col_name].astype('category')

print(data_train)
# Out:
#        Podcast_Name  Episode_Title  Episode_Length_minutes Genre  \
# 192104           14             84                   19.69     2
# 604876           23             73                   23.14     6
# 12284            21              4                   29.49     6
# 220731           41             30                  107.06     4
# 57552            14             30                    7.02     2
# ...             ...            ...                     ...   ...
# 339242           29             73                   50.67     9
# 725848           40             60                  100.20     4
# 644600           27             67                   53.01     8
# 437930           30             37                   71.63     1
# 184847            7             13                   68.07     7
#
#         Host_Popularity_percentage Publication_Day Publication_Time  \
# 192104                       38.27               4                0
# 604876                       89.50               2                2
# 12284                        60.87               4                1
# 220731                       83.97               2                3
# 57552                        24.53               4                1
# ...                            ...             ...              ...
# 339242                       34.55               0                0
# 725848                       56.29               4                3
# 644600                       54.83               0                2
# 437930                       80.84               3                2
# 184847                       43.56               0                1
#
#         Guest_Popularity_percentage  Number_of_Ads Episode_Sentiment  ...  \
# 192104                        91.16              0                 1  ...
# 604876                        93.21              3                 2  ...
# 12284                         78.84              2                 0  ...
# 220731                        92.57              0                 2  ...
# 57552                         30.90              1                 2  ...
# ...                             ...            ...               ...  ...
# 339242                        58.44              3                 2  ...
# 725848                        89.01              2                 2  ...
# 644600                        38.74              1                 2  ...
# 437930                        75.60              1                 1  ...
# 184847                        38.93              3                 0  ...
#
#         Host_Popularity_percentage_Publication_Day_Number_of_Ads_Episode_Sentiment  \
# 192104                                        38.27_4_0_1
# 604876                                         89.5_2_3_2
# 12284                                         60.87_4_2_0
# 220731                                        83.97_2_0_2
# 57552                                         24.53_4_1_2
# ...                                                   ...
# 339242                                        34.55_0_3_2
# 725848                                        56.29_4_2_2
# 644600                                        54.83_0_1_2
# 437930                                        80.84_3_1_1
# 184847                                        43.56_0_3_0
#
#        Host_Popularity_percentage_Publication_Time_Guest_Popularity_percentage_Number_of_Ads  \
# 192104                                    38.27_0_91.16_0
# 604876                                     89.5_2_93.21_3
# 12284                                     60.87_1_78.84_2
# 220731                                    83.97_3_92.57_0
# 57552                                      24.53_1_30.9_1
# ...                                                   ...
# 339242                                    34.55_0_58.44_3
# 725848                                    56.29_3_89.01_2
# 644600                                    54.83_2_38.74_1
# 437930                                     80.84_2_75.6_1
# 184847                                    43.56_1_38.93_3
#
#        Host_Popularity_percentage_Publication_Time_Guest_Popularity_percentage_Episode_Sentiment  \
# 192104                                    38.27_0_91.16_1
# 604876                                     89.5_2_93.21_2
# 12284                                     60.87_1_78.84_0
# 220731                                    83.97_3_92.57_2
# 57552                                      24.53_1_30.9_2
# ...                                                   ...
# 339242                                    34.55_0_58.44_2
# 725848                                    56.29_3_89.01_2
# 644600                                    54.83_2_38.74_2
# 437930                                     80.84_2_75.6_1
# 184847                                    43.56_1_38.93_0
#
#        Host_Popularity_percentage_Publication_Time_Number_of_Ads_Episode_Sentiment  \
# 192104                                        38.27_0_0_1
# 604876                                         89.5_2_3_2
# 12284                                         60.87_1_2_0
# 220731                                        83.97_3_0_2
# 57552                                         24.53_1_1_2
# ...                                                   ...
# 339242                                        34.55_0_3_2
# 725848                                        56.29_3_2_2
# 644600                                        54.83_2_1_2
# 437930                                        80.84_2_1_1
# 184847                                        43.56_1_3_0
#
#        Host_Popularity_percentage_Guest_Popularity_percentage_Number_of_Ads_Episode_Sentiment  \
# 192104                                    38.27_91.16_0_1
# 604876                                     89.5_93.21_3_2
# 12284                                     60.87_78.84_2_0
# 220731                                    83.97_92.57_0_2
# 57552                                      24.53_30.9_1_2
# ...                                                   ...
# 339242                                    34.55_58.44_3_2
# 725848                                    56.29_89.01_2_2
# 644600                                    54.83_38.74_1_2
# 437930                                     80.84_75.6_1_1
# 184847                                    43.56_38.93_3_0
#
#        Publication_Day_Publication_Time_Guest_Popularity_percentage_Number_of_Ads  \
# 192104                                        4_0_91.16_0
# 604876                                        2_2_93.21_3
# 12284                                         4_1_78.84_2
# 220731                                        2_3_92.57_0
# 57552                                          4_1_30.9_1
# ...                                                   ...
# 339242                                        0_0_58.44_3
# 725848                                        4_3_89.01_2
# 644600                                        0_2_38.74_1
# 437930                                         3_2_75.6_1
# 184847                                        0_1_38.93_3
#
#        Publication_Day_Publication_Time_Guest_Popularity_percentage_Episode_Sentiment  \
# 192104                                        4_0_91.16_1
# 604876                                        2_2_93.21_2
# 12284                                         4_1_78.84_0
# 220731                                        2_3_92.57_2
# 57552                                          4_1_30.9_2
# ...                                                   ...
# 339242                                        0_0_58.44_2
# 725848                                        4_3_89.01_2
# 644600                                        0_2_38.74_2
# 437930                                         3_2_75.6_1
# 184847                                        0_1_38.93_0
#
#        Publication_Day_Publication_Time_Number_of_Ads_Episode_Sentiment  \
# 192104                                            4_0_0_1
# 604876                                            2_2_3_2
# 12284                                             4_1_2_0
# 220731                                            2_3_0_2
# 57552                                             4_1_1_2
# ...                                                   ...
# 339242                                            0_0_3_2
# 725848                                            4_3_2_2
# 644600                                            0_2_1_2
# 437930                                            3_2_1_1
# 184847                                            0_1_3_0
#
#        Publication_Day_Guest_Popularity_percentage_Number_of_Ads_Episode_Sentiment  \
# 192104                                        4_91.16_0_1
# 604876                                        2_93.21_3_2
# 12284                                         4_78.84_2_0
# 220731                                        2_92.57_0_2
# 57552                                          4_30.9_1_2
# ...                                                   ...
# 339242                                        0_58.44_3_2
# 725848                                        4_89.01_2_2
# 644600                                        0_38.74_1_2
# 437930                                         3_75.6_1_1
# 184847                                        0_38.93_3_0
#
#        Publication_Time_Guest_Popularity_percentage_Number_of_Ads_Episode_Sentiment
# 192104                                        0_91.16_0_1
# 604876                                        2_93.21_3_2
# 12284                                         1_78.84_2_0
# 220731                                        3_92.57_0_2
# 57552                                          1_30.9_1_2
# ...                                                   ...
# 339242                                        0_58.44_3_2
# 725848                                        3_89.01_2_2
# 644600                                        2_38.74_1_2
# 437930                                         2_75.6_1_1
# 184847                                        1_38.93_3_0
#
# [539 rows x 386 columns]

# %%
len(data_train['Publication_Time_Guest_Popularity_percentage_Number_of_Ads_Episode_Sentiment'].unique())
# Out:
# 539

# %%
def target_encode(df_train, df_test, target_col, col_list):
    """ Target encode all columns listed in col_list, both in training and test DataFrames.
        (Using the mean of the target column from the training DataFrame.)
        Doing it like this, the target values from the validation fold are used in the mean,
        not just from the training folds - but that probably is ok.
    Args:
        df_train (pd.DataFrame): Training DataFrame.
        df_test (pd.DataFrame): Test DataFrame.
        target_col (str): Name of the target column to use for the encoding.
        col_list (List[str]): List of column names to target encode.
    Returns:
        Tuple[pd.DataFrame, pd.DataFrame]: Training and test DataFrames with encoded columns.
    """
    for col in col_list:
        groupby_df = df_train[[target_col, col]].groupby([col]).mean()
        groupby_df.sort_values(by=target_col, inplace=True)
        mapping_dict = groupby_df[target_col].to_dict()
        df_train[col] = df_train[col].map(mapping_dict).astype(float)
        df_test[col] = df_test[col].map(mapping_dict).astype(float)

    return (df_train, df_test)

category_columns = data_train.select_dtypes(include=['category', 'object']).columns.tolist()
data_train, data_test = target_encode(data_train, data_test, 'Listening_Time_minutes', category_columns)

# %%
categorical_columns = data_train.select_dtypes(include=['category', 'object']).columns.tolist()

print(categorical_columns)
# Out:
# ['Podcast_Name', 'Genre', 'Publication_Day', 'Publication_Time', 'Episode_Sentiment', 'Podcast_Name_Genre', 'Podcast_Name_Publication_Day', 'Podcast_Name_Publication_Time', 'Podcast_Name_Number_of_Ads', 'Podcast_Name_Episode_Sentiment', 'Episode_Title_Publication_Time', 'Episode_Title_Episode_Sentiment', 'Genre_Publication_Day', 'Genre_Publication_Time', 'Genre_Number_of_Ads', 'Genre_Episode_Sentiment', 'Publication_Day_Publication_Time', 'Publication_Day_Number_of_Ads', 'Publication_Day_Episode_Sentiment', 'Publication_Time_Number_of_Ads', 'Publication_Time_Episode_Sentiment', 'Number_of_Ads_Episode_Sentiment', 'Podcast_Name_Genre_Publication_Day', 'Podcast_Name_Genre_Publication_Time', 'Podcast_Name_Genre_Number_of_Ads', 'Podcast_Name_Genre_Episode_Sentiment', 'Podcast_Name_Publication_Time_Number_of_Ads', 'Podcast_Name_Publication_Time_Episode_Sentiment', 'Podcast_Name_Number_of_Ads_Episode_Sentiment', 'Genre_Publication_Day_Publication_Time', 'Genre_Publication_Day_Number_of_Ads', 'Genre_Publication_Day_Episode_Sentiment', 'Genre_Publication_Time_Number_of_Ads', 'Genre_Publication_Time_Episode_Sentiment', 'Genre_Number_of_Ads_Episode_Sentiment', 'Publication_Day_Publication_Time_Number_of_Ads', 'Publication_Day_Publication_Time_Episode_Sentiment', 'Publication_Day_Number_of_Ads_Episode_Sentiment', 'Publication_Time_Number_of_Ads_Episode_Sentiment', 'Podcast_Name_Genre_Publication_Time_Number_of_Ads', 'Podcast_Name_Genre_Publication_Time_Episode_Sentiment', 'Podcast_Name_Genre_Number_of_Ads_Episode_Sentiment', 'Genre_Publication_Day_Publication_Time_Number_of_Ads', 'Genre_Publication_Day_Publication_Time_Episode_Sentiment', 'Genre_Publication_Time_Number_of_Ads_Episode_Sentiment', 'Publication_Day_Publication_Time_Number_of_Ads_Episode_Sentiment']

# %%
data_train.sample(5)
# Out:
#        Podcast_Name  Episode_Title  Episode_Length_minutes      Genre  \
# 709483    32.426498             74                   34.30  39.550334
# 239961    45.330839             60                  111.95  41.497246
# 189242    56.378750             48                   97.10  50.391845
# 469449    37.964234              5                  105.34  41.497246
# 535271    61.473396             71                   65.98  53.325072
#
#         Host_Popularity_percentage Publication_Day Publication_Time  \
# 709483                       37.36       47.598365        49.415535
# 239961                       67.18       46.984605        49.415535
# 189242                       96.56       46.367820        45.724010
# 469449                       30.94       49.779779        49.415535
# 535271                       32.00       48.883059        49.415535
#
#         Guest_Popularity_percentage  Number_of_Ads Episode_Sentiment  ...  \
# 709483                        87.68              3         43.378716  ...
# 239961                        24.15              2         49.094071  ...
# 189242                        35.57              0         50.521189  ...
# 469449                        15.96              3         49.094071  ...
# 535271                        28.36              0         50.521189  ...
#
#         Host_Popularity_percentage_Publication_Day_Number_of_Ads_Episode_Sentiment  \
# 709483                                           20.22642
# 239961                                           67.60855
# 189242                                           96.57777
# 469449                                           83.40108
# 535271                                           50.58493
#
#         Host_Popularity_percentage_Publication_Time_Guest_Popularity_percentage_Number_of_Ads  \
# 709483                                           20.22642
# 239961                                           67.60855
# 189242                                           96.57777
# 469449                                           83.40108
# 535271                                           50.58493
#
#         Host_Popularity_percentage_Publication_Time_Guest_Popularity_percentage_Episode_Sentiment  \
# 709483                                           20.22642
# 239961                                           67.60855
# 189242                                           96.57777
# 469449                                           83.40108
# 535271                                           50.58493
#
#        Host_Popularity_percentage_Publication_Time_Number_of_Ads_Episode_Sentiment  \
# 709483                                           20.22642
# 239961                                           67.60855
# 189242                                           96.57777
# 469449                                           83.40108
# 535271                                           50.58493
#
#         Host_Popularity_percentage_Guest_Popularity_percentage_Number_of_Ads_Episode_Sentiment  \
# 709483                                           20.22642
# 239961                                           67.60855
# 189242                                           96.57777
# 469449                                           83.40108
# 535271                                           50.58493
#
#        Publication_Day_Publication_Time_Guest_Popularity_percentage_Number_of_Ads  \
# 709483                                           20.22642
# 239961                                           67.60855
# 189242                                           96.57777
# 469449                                           83.40108
# 535271                                           50.58493
#
#        Publication_Day_Publication_Time_Guest_Popularity_percentage_Episode_Sentiment  \
# 709483                                           20.22642
# 239961                                           67.60855
# 189242                                           96.57777
# 469449                                           83.40108
# 535271                                           50.58493
#
#         Publication_Day_Publication_Time_Number_of_Ads_Episode_Sentiment  \
# 709483                                          56.038575
# 239961                                          38.253397
# 189242                                          60.265820
# 469449                                          60.622502
# 535271                                          75.042255
#
#        Publication_Day_Guest_Popularity_percentage_Number_of_Ads_Episode_Sentiment  \
# 709483                                           20.22642
# 239961                                           67.60855
# 189242                                           96.57777
# 469449                                           83.40108
# 535271                                           50.58493
#
#        Publication_Time_Guest_Popularity_percentage_Number_of_Ads_Episode_Sentiment
# 709483                                           20.22642
# 239961                                           67.60855
# 189242                                           96.57777
# 469449                                           83.40108
# 535271                                           50.58493
#
# [5 rows x 386 columns]
