# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

data = pd.read_csv("train.csv")

data.sample(n=5)
# Out:
#             id   Age  Gender  Annual Income Marital Status  \
# 848624  848624  20.0  Female        15177.0        Married
# 961360  961360  46.0  Female        67522.0         Single
# 28960    28960  55.0    Male        18096.0       Divorced
# 539971  539971  41.0  Female          816.0         Single
# 649018  649018  25.0  Female         2791.0       Divorced
#
#         Number of Dependents Education Level     Occupation  Health Score  \
# 848624                   1.0      Bachelor's     Unemployed     10.580424
# 961360                   0.0             PhD       Employed     50.822510
# 28960                    4.0        Master's  Self-Employed     45.169968
# 539971                   1.0     High School  Self-Employed      7.062361
# 649018                   1.0      Bachelor's     Unemployed     43.093691
#
#         Location  ... Previous Claims  Vehicle Age  Credit Score  \
# 848624     Urban  ...             0.0          6.0           NaN
# ...

# %%
# replace unknown non-numerical values (or should I remove them?)
for key in ['Marital Status', 'Occupation', 'Customer Feedback']:
    data[key] = data[key].fillna('UNKNOWN')

# setting numerical column NaNs to median value for the column
for key in ['Annual Income', 'Number of Dependents', 'Health Score', 'Previous Claims', 'Vehicle Age', 'Credit Score', 'Insurance Duration']:
    data[key] = data[key].fillna(data[key].median())

# %%
sns.relplot(data=data, x="Annual Income", y="Premium Amount")

# %%
sns.relplot(data=data, x="Credit Score", y="Premium Amount")

# %%
sns.relplot(data=data, x="Health Score", y="Premium Amount")

# %%
sns.relplot(data=data, x="Previous Claims", y="Premium Amount")

# %%
sns.histplot(data=data, x="Premium Amount", hue="Education Level", element="poly")
# Out:
# <AxesSubplot:xlabel='Premium Amount', ylabel='Count'>

# %%
sns.histplot(data=data, x="Premium Amount", hue="Occupation", element="poly")
# Out:
# <AxesSubplot:xlabel='Premium Amount', ylabel='Count'>

# %%
sns.histplot(data=data, x="Premium Amount", hue="Smoking Status", element="poly")
# Out:
# <AxesSubplot:xlabel='Premium Amount', ylabel='Count'>

# %%
sns.histplot(data=data, x="Premium Amount", hue="Location", element="poly")
# Out:
# <AxesSubplot:xlabel='Premium Amount', ylabel='Count'>

# %%
sns.histplot(data=data, x="Health Score", hue="Smoking Status", element="poly")
# Out:
# <AxesSubplot:xlabel='Health Score', ylabel='Count'>

# %%
sns.histplot(data=data, x="Premium Amount", hue="Gender", element="poly")
# Out:
# <AxesSubplot:xlabel='Premium Amount', ylabel='Count'>
