# %%
import pandas as pd
import numpy as np
import seaborn as sns

data_train = pd.read_csv('train.csv')
data_test = pd.read_csv('test.csv')
data_train.sample(5)
# Out:
#             id     Podcast_Name Episode_Title  Episode_Length_minutes  \
# 409396  409396      Health Hour    Episode 46                   94.62
# 718327  718327        Humor Hub    Episode 40                   42.52
# 173975  173975   Digital Digest    Episode 38                   35.74
# 483371  483371      Sound Waves    Episode 99                   74.41
# 694392  694392  Fashion Forward    Episode 82                     NaN
#
#              Genre  Host_Popularity_percentage Publication_Day  \
# 409396      Health                       72.03        Thursday
# 718327      Comedy                       80.51          Monday
# 173975  Technology                       51.04         Tuesday
# 483371       Music                       43.17          Sunday
# 694392   Lifestyle                       80.85        Saturday
#
#        Publication_Time  Guest_Popularity_percentage  Number_of_Ads  \
# 409396            Night                        45.84            1.0
# 718327            Night                        38.55            0.0
# 173975          Evening                        19.08            0.0
# 483371          Evening                        97.53            3.0
# 694392        Afternoon                        11.74            3.0
#
#        Episode_Sentiment  Listening_Time_minutes
# 409396          Negative                73.37494
# 718327           Neutral                41.43918
# 173975           Neutral                19.71374
# 483371           Neutral                39.28556
# 694392           Neutral                22.32040

# %%
# clean data
def clean(dataframe):
    dataframe.drop('id', axis=1, inplace=True)
    dataframe.dropna(axis=0, how='any', inplace=True)
    dataframe.drop(dataframe[dataframe['Number_of_Ads']>10].index, inplace=True)
    dataframe.drop(dataframe[dataframe['Episode_Length_minutes']>250].index, inplace=True)
    dataframe['Episode_Title'] = dataframe['Episode_Title'].map(lambda et: int(et.split()[1]))
    dataframe['Episode_Sentiment'] = dataframe['Episode_Sentiment'].map({'Negative': -1, 'Neutral': 0, 'Positive': +1})
    dataframe['Number_of_Ads'] = dataframe['Number_of_Ads'].astype(int)

    return dataframe

data_train = clean(data_train)
data_test = clean(data_test)
data_train.sample(5)
# Out:
#         Podcast_Name  Episode_Title  Episode_Length_minutes       Genre  \
# 390661   Gadget Geek             79                   46.12  Technology
# 680568  Daily Digest             29                  103.49        News
# 87699    Style Guide            100                  111.89   Lifestyle
# 165825    Melody Mix             76                   71.22       Music
# 362842   Style Guide              2                  115.67   Lifestyle
#
#         Host_Popularity_percentage Publication_Day Publication_Time  \
# 390661                       53.17        Thursday          Morning
# 680568                       54.47          Friday            Night
# 87699                        54.84        Saturday        Afternoon
# 165825                       86.04        Thursday          Morning
# 362842                       43.57          Monday            Night
#
#         Guest_Popularity_percentage  Number_of_Ads  Episode_Sentiment  \
# 390661                        45.49              0                 -1
# 680568                        30.85              2                  0
# 87699                         74.81              1                  1
# 165825                        81.24              0                  0
# 362842                        19.67              3                  0
#
#         Listening_Time_minutes
# 390661                23.85158
# 680568                61.30796
# 87699                 71.58727
# 165825                48.02613
# 362842                58.19244

# %%
from collections import Counter

def check_duplicate_counts(mapping_dict):
    values = list(mapping_dict.values())
    return len(values) != len(set(values))

def count_encode(df_train, df_test, target_col, col_list):
    for col in col_list:
        mapping_dict_train = df_train[col].value_counts().to_dict()
        mapping_dict_test = df_test[col].value_counts().to_dict()
        
        mapping_dict = dict(Counter(mapping_dict_train) + Counter(mapping_dict_test))
        
        df_train[col] = df_train[col].map(mapping_dict).astype(int)
        df_test[col] = df_test[col].map(mapping_dict).astype(int)

    return (df_train, df_test)

data_train, data_test = count_encode(data_train, data_test, 'Listening_Time_minutes', ['Podcast_Name', 'Genre'])
data_train.sample(5)
# Out:
#         Podcast_Name  Episode_Title  Episode_Length_minutes  Genre  \
# 127953         16711              9                   61.11  80710
# 307899         13479             53                  112.08  81049
# 541732         12897             16                   64.63  75722
# 324573         15337             18                   36.53  79430
# 655663         19197             82                  106.55  69654
#
#         Host_Popularity_percentage Publication_Day Publication_Time  \
# 127953                       78.69          Friday          Evening
# 307899                       33.08        Saturday            Night
# 541732                       67.41        Thursday            Night
# 324573                       24.29        Thursday          Evening
# 655663                       39.63        Thursday            Night
#
#         Guest_Popularity_percentage  Number_of_Ads  Episode_Sentiment  \
# 127953                        57.44              1                  0
# 307899                        33.85              0                  1
# 541732                        94.57              3                  1
# 324573                        92.57              3                 -1
# 655663                         5.29              1                  0
#
#         Listening_Time_minutes
# 127953                58.80115
# 307899               108.78000
# 541732                44.17490
# 324573                29.98220
# 655663                88.55101

# %%
len(data_train)
# Out:
# 539040
