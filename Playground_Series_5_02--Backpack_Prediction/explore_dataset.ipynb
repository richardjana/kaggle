# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

data = pd.read_csv("train.csv")

data.sample(n=5)
# Out:
#             id         Brand   Material    Size  Compartments  \
# 191714  191714        Adidas      Nylon   Small           9.0
# 175818  175818  Under Armour  Polyester   Small           2.0
# 69463    69463      Jansport      Nylon   Small          10.0
# 179573  179573        Adidas     Canvas   Large           8.0
# 39930    39930  Under Armour    Leather  Medium          10.0
#
#        Laptop Compartment Waterproof      Style  Color  Weight Capacity (kg)  \
# 191714                Yes         No       Tote    Red             29.222322
# 175818                 No        Yes   Backpack  Green              9.957413
# 69463                 Yes        Yes   Backpack  Green              6.666725
# 179573                 No         No   Backpack    NaN             27.453813
# 39930                 Yes         No  Messenger  Green             10.914116
#
#             Price
# 191714  107.59018
# 175818   39.26343
# 69463   118.75062
# 179573  112.89469
# 39930   148.18470

# %%
full_len = len(data)
data.dropna(how='any', axis=0, inplace=True)
clean_len = len(data)
print(f"remaining {100/full_len*clean_len:.2f} % of the full dataset")
# Out:
# remaining 82.23 % of the full dataset

# %%
sns.histplot(data=data, x="Price", hue='Brand', element="poly")
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Count'>

# %%
sns.histplot(data=data, x="Price", hue='Material', element="poly")
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Count'>

# %%
sns.histplot(data=data, x="Price", hue='Size', element="poly")
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Count'>

# %%
sns.histplot(data=data, x="Price", hue='Compartments', element="poly")
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Count'>

# %%
sns.histplot(data=data, x="Price", hue='Laptop Compartment', element="poly")
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Count'>

# %%
sns.histplot(data=data, x="Price", hue='Waterproof', element="poly")
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Count'>

# %%
sns.histplot(data=data, x="Price", hue='Style', element="poly")
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Count'>

# %%
sns.histplot(data=data, x="Price", hue='Color', element="poly")
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Count'>

# %%
sns.scatterplot(data=data, x="Weight Capacity (kg)", y="Price", alpha=0.01)
# Out:
# <AxesSubplot:xlabel='Weight Capacity (kg)', ylabel='Price'>

# %%
# 2. One-Hot Encoding the Categorical Variable 'Car_Brand'
df_encoded = pd.get_dummies(data, columns=['Material'], dtype =int)  # drop_first to avoid multicollinearity
df_encoded
# Out:
#             id         Brand    Size  Compartments Laptop Compartment  \
# 0            0      Jansport  Medium           7.0                Yes
# 1            1      Jansport   Small          10.0                Yes
# 2            2  Under Armour   Small           2.0                Yes
# 3            3          Nike   Small           8.0                Yes
# 4            4        Adidas  Medium           1.0                Yes
# ...        ...           ...     ...           ...                ...
# 299995  299995        Adidas   Small           9.0                 No
# 299996  299996      Jansport   Large           6.0                 No
# 299997  299997          Puma   Large           9.0                Yes
# 299998  299998        Adidas   Small           1.0                 No
# 299999  299999  Under Armour   Small           2.0                 No
#
#        Waterproof      Style  Color  Weight Capacity (kg)      Price  \
# ...

# %%
plot = sns.histplot(data=data, x="Price", hue='Brand', element="poly")
plot.set_xlim([140, 150])
# Out:
# (140.0, 150.0)
