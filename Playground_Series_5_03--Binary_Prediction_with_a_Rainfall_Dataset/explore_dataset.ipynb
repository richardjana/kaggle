# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

data = pd.read_csv("train.csv")

data.sample(n=5)
# Out:
#         id  day  pressure  maxtemp  temparature  mintemp  dewpoint  humidity  \
# 895    895  166    1008.3     31.0         30.6     28.1      25.9      79.0
# 616    616  252    1014.5     30.1         28.2     26.6      20.4      79.0
# 815    815   86    1013.3     27.7         25.3     23.6      22.3      84.0
# 860    860  131    1007.5     32.0         29.9     27.7      24.3      91.0
# 1852  1852   28    1013.3     24.3         21.5     19.9      19.3      91.0
#
#       cloud  sunshine  winddirection  windspeed  rainfall
# 895    79.0       3.7          220.0       12.8         1
# 616    46.0      10.3           70.0       31.8         0
# 815    90.0       1.1           60.0        6.6         1
# 860    85.0       6.2          220.0       25.0         1
# 1852   78.0       1.5           40.0       14.5         1

# %%
full_len = len(data)
data.dropna(how='any', axis=0, inplace=True)
clean_len = len(data)
print(f"remaining {100/full_len*clean_len:.2f} % of the full dataset")
# Out:
# remaining 100.00 % of the full dataset

# %%
sns.scatterplot(data=data, x="humidity", y="rainfall", alpha=0.1)
# Out:
# <AxesSubplot:xlabel='humidity', ylabel='rainfall'>

# %%
sns.scatterplot(data=data, x="pressure", y="rainfall", alpha=0.1)
# Out:
# <AxesSubplot:xlabel='pressure', ylabel='rainfall'>

# %%
sns.scatterplot(data=data, x="mintemp", y="maxtemp", alpha=0.1)
# Out:
# <AxesSubplot:xlabel='mintemp', ylabel='maxtemp'>

# %%
sns.scatterplot(data=data, x="cloud", y="rainfall", alpha=0.1)
# Out:
# <AxesSubplot:xlabel='cloud', ylabel='rainfall'>

# %%
sns.scatterplot(data=data, x="humidity", y="cloud", alpha=0.1)
# Out:
# <AxesSubplot:xlabel='humidity', ylabel='cloud'>

# %%
data['rainfall'].mean()
# Out:
# 0.7534246575342466

# %%
# as noted in the discussions on kaggle, the day column is suspicious! might be worth fixing?
sns.scatterplot(data=data, x="id", y="day")
# Out:
# <AxesSubplot:xlabel='id', ylabel='day'>

# %%
data['day_fixed'] = (data['id'] + data['day'][0])% 365
sns.scatterplot(data=data, x="id", y="day_fixed")
# Out:
# <AxesSubplot:xlabel='id', ylabel='day_fixed'>

# %%
data.sample(n=5)
# Out:
#         id  day  pressure  maxtemp  temparature  mintemp  dewpoint  humidity  \
# 713    713  349    1022.7     15.8         15.2     14.0      11.4      89.0
# 580    580  216    1005.9     30.7         27.9     26.6      24.3      84.0
# 1474  1474   15    1024.3     17.5         13.1     11.4       3.1      58.0
# 1289  1289  195    1007.9     32.3         29.1     28.9      26.4      79.0
# 2103  2103  279    1014.9     26.2         24.5     24.0      21.4      78.0
#
#       cloud  sunshine  winddirection  windspeed  rainfall  day_fixed
# 713    88.0       0.3           70.0       39.5         1        349
# 580    78.0       7.6          220.0       14.8         1        216
# 1474   81.0       0.0           20.0       14.6         1         15
# 1289   78.0       8.2          270.0       25.1         1        195
# 2103   82.0       2.3           80.0       37.5         1        279

# %%
sns.scatterplot(data=data, x="day", y="day_fixed")
# Out:
# <AxesSubplot:xlabel='day', ylabel='day_fixed'>

# %%
data = pd.read_csv("test.csv")

# %%
sns.scatterplot(data=data, x="id", y="day")
# Out:
# <AxesSubplot:xlabel='id', ylabel='day'>

# %%
data['day_fixed'] = data['id'] % 365
sns.scatterplot(data=data, x="id", y="day_fixed")
# Out:
# <AxesSubplot:xlabel='id', ylabel='day_fixed'>

# %%
data.sample(n=5)
# Out:
#        id  day  pressure  maxtemp  temparature  mintemp  dewpoint  humidity  \
# 630  2820  266    1012.7     30.3         27.5     24.0      23.2      75.0
# 470  2660  106    1009.1     30.0         27.4     24.5      25.0      80.0
# 138  2328  139    1008.4     29.5         27.8     24.4      25.4      85.0
# 680  2870  316    1017.1     24.2         20.8     19.2      16.9      76.0
# 342  2532  343    1025.9     18.9         17.9     15.8      14.9      79.0
#
#      cloud  sunshine  winddirection  windspeed  day_fixed
# 630   51.0       8.5          110.0       15.8        265
# 470   84.0       3.5           80.0       12.6        105
# 138   86.0       1.0          180.0       20.2        138
# 680   49.0       7.7           20.0        9.1        315
# 342   83.0       1.1           60.0       22.2        342

# %%
df_nan = data[data.isna().any(axis=1)]
df_nan.sample()
# Out:
#        id  day  pressure  maxtemp  temparature  mintemp  dewpoint  humidity  \
# 517  2707  153    1007.8     32.9         30.6     28.9      22.0      65.0
#
#      cloud  sunshine  winddirection  windspeed
# 517   75.0       8.2            NaN       17.2

# %%
full_len = len(data)
data.dropna(how='any', axis=0, inplace=True)
clean_len = len(data)
print(f"remaining {100/full_len*clean_len:.2f} % of the full dataset")

# %%
day_circ = pd.read_csv("day_circ.csv")
day_circ['id'] = np.arange(0, len(day_circ))
sns.scatterplot(data=day_circ, x="day_sin", y="day_cos", c=day_circ["id"])
# Out:
# <AxesSubplot:xlabel='day_sin', ylabel='day_cos'>
